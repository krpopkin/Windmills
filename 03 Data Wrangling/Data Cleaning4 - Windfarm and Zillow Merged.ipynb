# %%
import warnings

# %%
#Imports
import pandas as pd

# %%
#Load the cleaned zillow csv file to a dataframe
# %cd C:\Users\Ken\Documents\KenP\Applications-DataScience\SpringboardCourseWork\CapstoneProject1Repository\09 CapstoneProject1Data\ZillowData

df_zi = pd.read_csv('project1_housing_data.csv')
#df_zi = pd.read_csv('junk_zi2.csv')

df_zi = df_zi.sort_values(by=['ZipCode'])

df_zi.head(1)
# Out:
# C:\Users\Ken\Documents\KenP\Applications-DataScience\SpringboardCourseWork\CapstoneProject1Repository\09 CapstoneProject1Data\ZillowData
#       Unnamed: 0  ZipCode      StateName  2008-03  2008-04  2008-05  2008-06  \
# 3082        3082     1001  Massachusetts      NaN      NaN      NaN      NaN
#
#       2008-07  2008-08  2008-09   ...      2017-11   2017-12   2018-01  \
# 3082      NaN      NaN      NaN   ...     198400.0  190500.0  166700.0
#
#        2018-02   2018-03   2018-04   2018-05   2018-06   2018-07  2018-08
# 3082  163700.0  155200.0  177100.0  182800.0  198000.0  202700.0      NaN
#
# [1 rows x 129 columns]

# %%
#Load the cleaned & expanded windfarm csv file to a dataframe
# %cd C:\Users\Ken\Documents\KenP\Applications-DataScience\SpringboardCourseWork\CapstoneProject1Repository\09 CapstoneProject1Data\WindfarmData

df_wf = pd.read_csv('project1_windfarm_data_expanded.csv')
#df_wf = pd.read_csv('junk_wf2.csv')

df_wf = df_wf.sort_values(by=['zipcode'])

df_wf.head(1)
# Out:
# C:\Users\Ken\Documents\KenP\Applications-DataScience\SpringboardCourseWork\CapstoneProject1Repository\09 CapstoneProject1Data\WindfarmData
#        Unnamed: 0  Unnamed: 0.1 state                  county   fips  \
# 43335       43335         43335    PR  Santa Isabel Municipio  72133
#
#        project_name  project_op_year  windmills_count  capacity  longitude  \
# 43335  Santa Isabel             2012               44     101.2 -66.376953
#
#        latitude  zipcode  pop_density  med_household_income
# 43335  17.97452      704       1759.0                   NaN

# %%
#Change directory to MergedData

# %cd C:\Users\Ken\Documents\KenP\Applications-DataScience\SpringboardCourseWork\CapstoneProject1Downloads\MergedData
# Out:
# [WinError 3] The system cannot find the path specified: 'C:\\Users\\Ken\\Documents\\KenP\\Applications-DataScience\\SpringboardCourseWork\\CapstoneProject1Downloads\\MergedData'
# C:\Users\Ken\Documents\KenP\Applications-DataScience\SpringboardCourseWork\CapstoneProject1Repository\09 CapstoneProject1Data\WindfarmData

# %%
#Merge the windfarm and zillow dataframes on zip code, as inner join, and write to a csv file.

df_me = pd.merge(left=df_wf, right=df_zi, on=None, left_on='zipcode', right_on='ZipCode')
df_me2 = df_me.drop(df_me.columns[1],axis=1)
df_me2 = df_me2.drop(df_me2.columns[0],axis=1)

# %%
df_me2.head(1)
# Out:
#   state            county   fips                     project_name  \
# 0    MA  Worcester County  25027  Nature's Classroom Wind Turbine
#
#    project_op_year  windmills_count  capacity  longitude   latitude  zipcode  \
# 0             2009                1       0.1 -72.003899  42.110889     1507
#
#     ...      2017-11   2017-12   2018-01   2018-02   2018-03   2018-04  \
# 0   ...     290300.0  279200.0  276000.0  252000.0  244500.0  259900.0
#
#     2018-05   2018-06   2018-07  2018-08
# 0  287800.0  295100.0  289100.0      NaN
#
# [1 rows x 141 columns]

# %%
out_csv = 'merged_wi_and_zi.csv'
df_me2.to_csv(out_csv)

# %%
df_me2.describe()
# Out:
#                fips  project_op_year  windmills_count     capacity  \
# count   5830.000000      5830.000000      5830.000000  5830.000000
# mean    6380.639451      1976.305832       766.011149 -3538.809182
# std     3324.633827       384.541916       806.723888  4813.667986
# min     6001.000000     -9999.000000         1.000000 -9999.000000
# 25%     6029.000000      1982.000000        68.000000 -9999.000000
# 50%     6029.000000      1985.000000       201.000000    10.435000
# 75%     6029.000000      1987.000000      1831.000000    27.000000
# max    53061.000000      2017.000000      1831.000000   180.000000
#
#          longitude     latitude       zipcode   pop_density  \
# count  5830.000000  5830.000000   5830.000000   5830.000000
# mean   -118.327973    35.476065  93104.358834    317.496055
# std       4.020166     1.400819   6418.369513    490.706555
# min    -122.679672    31.715195   1507.000000    118.000000
# ...
